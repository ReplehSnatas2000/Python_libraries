# %%
import pandas as pd
import numpy as np
import cufflinks as cf
from plotly.offline import download_plotlyjs, init_notebook_mode, iplot, plot

# %%
init_notebook_mode(connected=True)
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
df = pd.DataFrame(np.random.randn(100, 4), columns="A B C D".split())
df
# Out:
#            A         B         C         D
# 0   0.720491  0.660465 -0.681283  0.285006
# 1   1.958268 -0.614924 -0.545874  0.411462
# 2   0.549971  0.340948 -1.145648  1.514813
# 3  -0.797076 -0.234670 -0.041091  0.567626
# 4   1.620307  0.203568  1.266101 -0.324199
# ..       ...       ...       ...       ...
# 95  0.590800 -2.245070  0.186351  0.162610
# 96 -0.659918 -0.211284 -1.244733 -2.251806
# 97  0.096994  2.019463  0.352275  1.559067
# 98 -0.681914  2.770444 -1.188929 -0.683800
# 99 -0.609247  1.385218  0.455594  1.225606
#
# [100 rows x 4 columns]

# %%
df2 = pd.DataFrame({"Category": "A B C".split(), "Values": [32, 43, 56]})
df2
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      56

# %%
# df.iplot()
# Out:
# <div>                            <div id="c2bed930-5c95-49bc-9a3b-101b93c6928b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# df.iplot(kind="hist")
# Out:
# <div>                            <div id="bc715beb-fc07-42e3-8217-2d50daeba385" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# df2.iplot(kind="scatter", x="Category", y="Values", mode="markers")
# Out:
# <div>                            <div id="1974384b-3bd3-41b4-8164-b07b8c1294a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
print(df["A"].sum(), df["B"].sum(), df["C"].sum(), df["D"].sum())
df.sum().iplot(kind="bar")
# Out:
# 0.8302046199814916 -3.1128977813960246 -12.34687179111027 -3.90325993711304
# <div>                            <div id="4a1eee86-aa52-450f-b6c4-86ba74d965ad" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
print(df["A"].max(), df[df["A"] <= 0.5926637]["A"].count())
# df.iplot(kind="box")
# Out:
# 2.61768762753595 75
# <div>                            <div id="acfaae42-327b-4631-98fd-d1ee792089f5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df3 = pd.DataFrame({"A": [1, 2, 3, 4, 5], "B": [
                   10, 20, 30, 20, 10], "C": [500, 400, 300, 200, 100]})
# df3.iplot(kind="surface", colorscale="rdylbu")
# Out:
# <div>                            <div id="05ff8f69-2e8d-4f17-808a-4f13f4dfe7ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# df3.iplot(kind="bubble", x="A", y="B", size="C")
# Out:
# <div>                            <div id="eae53cfe-45e0-43af-a20f-a5299e4fc2c8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
print(df3)
# df3.scatter_matrix()
# Out:
#    A   B    C
# 0  1  10  500
# 1  2  20  400
# 2  3  30  300
# 3  4  20  200
# 4  5  10  100
# <div>                            <div id="a1aeb061-2049-4cba-b5ca-b6a6e4e0160f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
# df3.iplot(kind="area")
# Out:
# <div>                            <div id="8aef078a-3c93-47c3-bece-2207a78e2b4e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
